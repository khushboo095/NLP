# %%
# !pip install spacy

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
doc=nlp('i m learning the datascience ')

# %%
doc.text
# Out:
# 'i m learning the datascience '

# %%
doc[0]
# Out:
# i

# %%
doc[0].pos_
# Out:
# 'PRON'

# %%
doc[1].pos_
# Out:
# 'AUX'

# %%
doc[1].tag_
# Out:
# 'VBP'

# %%
spacy.explain('VBP')
# Out:
# 'verb, non-3rd person singular present'

# %%
spacy.explain('AUX')
# Out:
# 'auxiliary'

# %%
# for i in doc:
#     print(doc.text,doc[i].pos_,doc[i].tag_,spacy.explain('doc[i].pos_'))

# %%
for i in doc:
    print(i.text,i.pos_,i.tag_,spacy.explain(i.tag_))
# Out:
# i PRON PRP pronoun, personal
# m AUX VBP verb, non-3rd person singular present
# learning VERB VBG verb, gerund or present participle
# the DET DT determiner
# datascience NOUN NN noun, singular or mass

# %%
doc1=nlp('i m reading the nlp')

# %%
for i in doc1:
    print(i.text,i.pos_,i.tag_,spacy.explain(i.tag_))
# Out:
# i PRON PRP pronoun, personal
# m AUX VBP verb, non-3rd person singular present
# reading VERB VBG verb, gerund or present participle
# the DET DT determiner
# nlp NOUN NN noun, singular or mass

# %%
doc2=nlp('the quick brown fox jumped over the lazy dog')

# %%
for i in doc2:
    print(i.text,i.pos_,i.tag_,spacy.explain(i.tag_))
# Out:
# the DET DT determiner
# quick ADJ JJ adjective (English), other noun-modifier (Chinese)
# brown ADJ JJ adjective (English), other noun-modifier (Chinese)
# fox NOUN NN noun, singular or mass
# jumped VERB VBD verb, past tense
# over ADP IN conjunction, subordinating or preposition
# the DET DT determiner
# lazy ADJ JJ adjective (English), other noun-modifier (Chinese)
# dog NOUN NN noun, singular or mass

# %%
from spacy import displacy

# %%
displacy.render(doc2,style='dep',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e0d49885dc014015bffd624d310b1f4d-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
# ...

# %%
options=(
    
    "distance":80,
    "compact":True,
    "color":'#fff',
    "bg":'#00a65a'
)
# Out:
#   Cell In[62], line 3
#     'distance':80,
#               ^
# SyntaxError: invalid syntax

# %%
displacy.render(doc2,style='dep',jupyter=True,options=options)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 displacy.render(doc2,style='dep',jupyter=True,options=options)
#
# NameError: name 'options' is not defined
